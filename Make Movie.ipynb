# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from glob import glob
import numpy as np
# Peak detection
from scipy.spatial import cKDTree as KDTree
import sys
import os
import tempfile
import hyperspy.api as hs
import skimage.io
# Out:
# /usr/local/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:hyperspy.api:The ipywidgets GUI elements are not available, probably because the hyperspy_gui_ipywidgets package is not installed.
# WARNING:hyperspy.api:The traitsui GUI elements are not available, probably because the hyperspy_gui_traitui package is not installed.

# %%
imgroot = 'experiment/Au-CeO2__200_CO_7_250'
atomsroot = imgroot + '_atoms'

# %%
def namegenerator(imgroot, dataroot):
    for root, dirs, files in os.walk(imgroot):
        dirs.sort()
        files.sort()
        for f in files:
            fullname = os.path.join(root, f)
            f_noext, ext = os.path.splitext(fullname)
            if ext not in ['.dm4', '.png']:
                continue
            assert f_noext.startswith(imgroot)
            dataname = dataroot + f_noext[len(imgroot):] + '_atoms.npy'
            yield fullname, dataname

# %%
names = namegenerator(imgroot, atomsroot)

# %%
def get_image(f):
    if f.endswith('.dm4'):
        a = hs.load(f)
        image = a.data
    else:
        a = skimage.io.imread(f)
        image = skimage.color.rgb2gray(a)
    return image

# %%
def get_points(f):
    atoms = np.load(f)
    return atoms

# %%
def crop(image, atoms, xmin=0, xmax=None, ymin=0, ymax=None):
    shape = image.shape
    if xmax is None:
        xmax = shape[0]
    if ymax is None:
        ymax = shape[1]
    image = image[xmin:xmax,ymin:ymax]
    d = 5
    atoms = atoms[np.where(atoms[:,0] > xmin + d)]
    atoms = atoms[np.where(atoms[:,1] > ymin + d)]
    atoms = atoms[np.where(atoms[:,0] < xmax - d)]
    atoms = atoms[np.where(atoms[:,1] < ymax - d)]
    atoms = atoms - np.array((xmin, ymin))
    return image, atoms

# %%
def makefigure(image, atoms, plotfile):
    #image, atoms = crop(image, atoms, xmin=500, xmax=1150, ymin=150, ymax=800)

    ig, (ax_raw, ax_atoms) = plt.subplots(1,2,figsize=(20,10))
    im1 = ax_raw.imshow(image,cmap='gray')
    #im2 = ax2.imshow(img2[0,:,:,0].T,cmap='gray')
    im3 = ax_atoms.imshow(image, cmap='gray')
    ax_atoms.scatter(atoms[:,1], atoms[:,0], c='#80FFFF', marker='o', linewidth=2.0)
    ax_raw.axis('off')
    ax_atoms.axis('off')
    plt.tight_layout()
    ig.savefig(plotfile, bbox_inches='tight')
    plt.close(ig)

# %%
#with tempfile.TemporaryDirectory() as tmpdir:
tmpdirectory = tempfile.TemporaryDirectory()
tmpdir = tmpdirectory.name
filenames = os.path.join(tmpdir, 'files.txt')
with open(filenames, "wt") as f:
    print("Temporary folder:", tmpdir)
    for i, (fi, fd) in enumerate(names):
        image = get_image(fi)
        atoms = get_points(fd)
        print(fi)
        pngfile = 'a{:04d}.png'.format(i)
        plotfile = os.path.join(tmpdir, pngfile)
        makefigure(image, atoms, plotfile)
        f.write(plotfile + '\n')
        #if i == 25: break
# Out:
# Temporary folder: /var/folders/cq/5k4g7j_j5q3crgmh_glgp8yr0000gn/T/tmpnrjzmoc7
# experiment/Au-CeO2__200_CO_7_250/frame00001.png
# experiment/Au-CeO2__200_CO_7_250/frame00002.png
# experiment/Au-CeO2__200_CO_7_250/frame00003.png
# experiment/Au-CeO2__200_CO_7_250/frame00004.png
# experiment/Au-CeO2__200_CO_7_250/frame00005.png
# experiment/Au-CeO2__200_CO_7_250/frame00006.png
# experiment/Au-CeO2__200_CO_7_250/frame00007.png
# experiment/Au-CeO2__200_CO_7_250/frame00008.png
# experiment/Au-CeO2__200_CO_7_250/frame00009.png
# experiment/Au-CeO2__200_CO_7_250/frame00010.png
# experiment/Au-CeO2__200_CO_7_250/frame00011.png
# experiment/Au-CeO2__200_CO_7_250/frame00012.png
# experiment/Au-CeO2__200_CO_7_250/frame00013.png
# experiment/Au-CeO2__200_CO_7_250/frame00014.png
# experiment/Au-CeO2__200_CO_7_250/frame00015.png
# experiment/Au-CeO2__200_CO_7_250/frame00016.png
# experiment/Au-CeO2__200_CO_7_250/frame00017.png
# experiment/Au-CeO2__200_CO_7_250/frame00018.png
# experiment/Au-CeO2__200_CO_7_250/frame00019.png
# experiment/Au-CeO2__200_CO_7_250/frame00020.png
# experiment/Au-CeO2__200_CO_7_250/frame00021.png
# experiment/Au-CeO2__200_CO_7_250/frame00022.png
# experiment/Au-CeO2__200_CO_7_250/frame00023.png
# experiment/Au-CeO2__200_CO_7_250/frame00024.png
# experiment/Au-CeO2__200_CO_7_250/frame00025.png
# experiment/Au-CeO2__200_CO_7_250/frame00026.png
# experiment/Au-CeO2__200_CO_7_250/frame00027.png
# experiment/Au-CeO2__200_CO_7_250/frame00028.png
# experiment/Au-CeO2__200_CO_7_250/frame00029.png
# experiment/Au-CeO2__200_CO_7_250/frame00030.png
# experiment/Au-CeO2__200_CO_7_250/frame00031.png
# experiment/Au-CeO2__200_CO_7_250/frame00032.png
# experiment/Au-CeO2__200_CO_7_250/frame00033.png
# experiment/Au-CeO2__200_CO_7_250/frame00034.png
# experiment/Au-CeO2__200_CO_7_250/frame00035.png
# experiment/Au-CeO2__200_CO_7_250/frame00036.png
# experiment/Au-CeO2__200_CO_7_250/frame00037.png
# experiment/Au-CeO2__200_CO_7_250/frame00038.png
# experiment/Au-CeO2__200_CO_7_250/frame00039.png
# experiment/Au-CeO2__200_CO_7_250/frame00040.png
# experiment/Au-CeO2__200_CO_7_250/frame00041.png
# experiment/Au-CeO2__200_CO_7_250/frame00042.png
# experiment/Au-CeO2__200_CO_7_250/frame00043.png
# experiment/Au-CeO2__200_CO_7_250/frame00044.png
# experiment/Au-CeO2__200_CO_7_250/frame00045.png
# experiment/Au-CeO2__200_CO_7_250/frame00046.png
# experiment/Au-CeO2__200_CO_7_250/frame00047.png
# experiment/Au-CeO2__200_CO_7_250/frame00048.png
# experiment/Au-CeO2__200_CO_7_250/frame00049.png
# experiment/Au-CeO2__200_CO_7_250/frame00050.png
# experiment/Au-CeO2__200_CO_7_250/frame00051.png
# experiment/Au-CeO2__200_CO_7_250/frame00052.png
# experiment/Au-CeO2__200_CO_7_250/frame00053.png
# experiment/Au-CeO2__200_CO_7_250/frame00054.png
# experiment/Au-CeO2__200_CO_7_250/frame00055.png
# experiment/Au-CeO2__200_CO_7_250/frame00056.png
# experiment/Au-CeO2__200_CO_7_250/frame00057.png
# experiment/Au-CeO2__200_CO_7_250/frame00058.png
# experiment/Au-CeO2__200_CO_7_250/frame00059.png
# experiment/Au-CeO2__200_CO_7_250/frame00060.png
# experiment/Au-CeO2__200_CO_7_250/frame00061.png
# experiment/Au-CeO2__200_CO_7_250/frame00062.png
# experiment/Au-CeO2__200_CO_7_250/frame00063.png
# experiment/Au-CeO2__200_CO_7_250/frame00064.png
# experiment/Au-CeO2__200_CO_7_250/frame00065.png
# experiment/Au-CeO2__200_CO_7_250/frame00066.png
# experiment/Au-CeO2__200_CO_7_250/frame00067.png
# experiment/Au-CeO2__200_CO_7_250/frame00068.png
# experiment/Au-CeO2__200_CO_7_250/frame00069.png
# experiment/Au-CeO2__200_CO_7_250/frame00070.png
# experiment/Au-CeO2__200_CO_7_250/frame00071.png
# experiment/Au-CeO2__200_CO_7_250/frame00072.png
# experiment/Au-CeO2__200_CO_7_250/frame00073.png
# experiment/Au-CeO2__200_CO_7_250/frame00074.png
# experiment/Au-CeO2__200_CO_7_250/frame00075.png
# experiment/Au-CeO2__200_CO_7_250/frame00076.png
# experiment/Au-CeO2__200_CO_7_250/frame00077.png
# experiment/Au-CeO2__200_CO_7_250/frame00078.png
# experiment/Au-CeO2__200_CO_7_250/frame00079.png
# experiment/Au-CeO2__200_CO_7_250/frame00080.png
# experiment/Au-CeO2__200_CO_7_250/frame00081.png
# experiment/Au-CeO2__200_CO_7_250/frame00082.png
# experiment/Au-CeO2__200_CO_7_250/frame00083.png
# experiment/Au-CeO2__200_CO_7_250/frame00084.png
# experiment/Au-CeO2__200_CO_7_250/frame00085.png
# experiment/Au-CeO2__200_CO_7_250/frame00086.png
# experiment/Au-CeO2__200_CO_7_250/frame00087.png
# experiment/Au-CeO2__200_CO_7_250/frame00088.png
# experiment/Au-CeO2__200_CO_7_250/frame00089.png
# experiment/Au-CeO2__200_CO_7_250/frame00090.png
# experiment/Au-CeO2__200_CO_7_250/frame00091.png
# experiment/Au-CeO2__200_CO_7_250/frame00092.png
# experiment/Au-CeO2__200_CO_7_250/frame00093.png
# experiment/Au-CeO2__200_CO_7_250/frame00094.png
# experiment/Au-CeO2__200_CO_7_250/frame00095.png
# experiment/Au-CeO2__200_CO_7_250/frame00096.png
# experiment/Au-CeO2__200_CO_7_250/frame00097.png
# experiment/Au-CeO2__200_CO_7_250/frame00098.png
# experiment/Au-CeO2__200_CO_7_250/frame00099.png
# experiment/Au-CeO2__200_CO_7_250/frame00100.png
# experiment/Au-CeO2__200_CO_7_250/frame00101.png
# experiment/Au-CeO2__200_CO_7_250/frame00102.png
# experiment/Au-CeO2__200_CO_7_250/frame00103.png
# experiment/Au-CeO2__200_CO_7_250/frame00104.png
# experiment/Au-CeO2__200_CO_7_250/frame00105.png
# experiment/Au-CeO2__200_CO_7_250/frame00106.png
# experiment/Au-CeO2__200_CO_7_250/frame00107.png
# experiment/Au-CeO2__200_CO_7_250/frame00108.png
# experiment/Au-CeO2__200_CO_7_250/frame00109.png
# experiment/Au-CeO2__200_CO_7_250/frame00110.png
# experiment/Au-CeO2__200_CO_7_250/frame00111.png
# experiment/Au-CeO2__200_CO_7_250/frame00112.png
# experiment/Au-CeO2__200_CO_7_250/frame00113.png
# experiment/Au-CeO2__200_CO_7_250/frame00114.png
# experiment/Au-CeO2__200_CO_7_250/frame00115.png
# experiment/Au-CeO2__200_CO_7_250/frame00116.png
# experiment/Au-CeO2__200_CO_7_250/frame00117.png
# experiment/Au-CeO2__200_CO_7_250/frame00118.png
# experiment/Au-CeO2__200_CO_7_250/frame00119.png
# experiment/Au-CeO2__200_CO_7_250/frame00120.png
# experiment/Au-CeO2__200_CO_7_250/frame00121.png
# experiment/Au-CeO2__200_CO_7_250/frame00122.png
# experiment/Au-CeO2__200_CO_7_250/frame00123.png
# experiment/Au-CeO2__200_CO_7_250/frame00124.png
# experiment/Au-CeO2__200_CO_7_250/frame00125.png
# experiment/Au-CeO2__200_CO_7_250/frame00126.png
# experiment/Au-CeO2__200_CO_7_250/frame00127.png
# experiment/Au-CeO2__200_CO_7_250/frame00128.png
# experiment/Au-CeO2__200_CO_7_250/frame00129.png
# experiment/Au-CeO2__200_CO_7_250/frame00130.png
# experiment/Au-CeO2__200_CO_7_250/frame00131.png
# experiment/Au-CeO2__200_CO_7_250/frame00132.png
# experiment/Au-CeO2__200_CO_7_250/frame00133.png
# experiment/Au-CeO2__200_CO_7_250/frame00134.png
# experiment/Au-CeO2__200_CO_7_250/frame00135.png
# experiment/Au-CeO2__200_CO_7_250/frame00136.png
# experiment/Au-CeO2__200_CO_7_250/frame00137.png
# experiment/Au-CeO2__200_CO_7_250/frame00138.png
# experiment/Au-CeO2__200_CO_7_250/frame00139.png
# experiment/Au-CeO2__200_CO_7_250/frame00140.png
# experiment/Au-CeO2__200_CO_7_250/frame00141.png
# experiment/Au-CeO2__200_CO_7_250/frame00142.png
# experiment/Au-CeO2__200_CO_7_250/frame00143.png
# experiment/Au-CeO2__200_CO_7_250/frame00144.png
# experiment/Au-CeO2__200_CO_7_250/frame00145.png
# experiment/Au-CeO2__200_CO_7_250/frame00146.png
# experiment/Au-CeO2__200_CO_7_250/frame00147.png
# experiment/Au-CeO2__200_CO_7_250/frame00148.png
# experiment/Au-CeO2__200_CO_7_250/frame00149.png
# experiment/Au-CeO2__200_CO_7_250/frame00150.png
# experiment/Au-CeO2__200_CO_7_250/frame00151.png
# experiment/Au-CeO2__200_CO_7_250/frame00152.png
# experiment/Au-CeO2__200_CO_7_250/frame00153.png
# experiment/Au-CeO2__200_CO_7_250/frame00154.png
# experiment/Au-CeO2__200_CO_7_250/frame00155.png
# experiment/Au-CeO2__200_CO_7_250/frame00156.png
# experiment/Au-CeO2__200_CO_7_250/frame00157.png
# experiment/Au-CeO2__200_CO_7_250/frame00158.png
# experiment/Au-CeO2__200_CO_7_250/frame00159.png
# experiment/Au-CeO2__200_CO_7_250/frame00160.png
# experiment/Au-CeO2__200_CO_7_250/frame00161.png
# experiment/Au-CeO2__200_CO_7_250/frame00162.png
# experiment/Au-CeO2__200_CO_7_250/frame00163.png
# experiment/Au-CeO2__200_CO_7_250/frame00164.png
# experiment/Au-CeO2__200_CO_7_250/frame00165.png
# experiment/Au-CeO2__200_CO_7_250/frame00166.png
# experiment/Au-CeO2__200_CO_7_250/frame00167.png
# experiment/Au-CeO2__200_CO_7_250/frame00168.png
# experiment/Au-CeO2__200_CO_7_250/frame00169.png
# experiment/Au-CeO2__200_CO_7_250/frame00170.png
# experiment/Au-CeO2__200_CO_7_250/frame00171.png
# experiment/Au-CeO2__200_CO_7_250/frame00172.png
# experiment/Au-CeO2__200_CO_7_250/frame00173.png
# experiment/Au-CeO2__200_CO_7_250/frame00174.png
# experiment/Au-CeO2__200_CO_7_250/frame00175.png
# experiment/Au-CeO2__200_CO_7_250/frame00176.png
# experiment/Au-CeO2__200_CO_7_250/frame00177.png
# experiment/Au-CeO2__200_CO_7_250/frame00178.png
# experiment/Au-CeO2__200_CO_7_250/frame00179.png
# experiment/Au-CeO2__200_CO_7_250/frame00180.png
# experiment/Au-CeO2__200_CO_7_250/frame00181.png
# experiment/Au-CeO2__200_CO_7_250/frame00182.png
# experiment/Au-CeO2__200_CO_7_250/frame00183.png
# experiment/Au-CeO2__200_CO_7_250/frame00184.png
# experiment/Au-CeO2__200_CO_7_250/frame00185.png
# experiment/Au-CeO2__200_CO_7_250/frame00186.png
# experiment/Au-CeO2__200_CO_7_250/frame00187.png
# experiment/Au-CeO2__200_CO_7_250/frame00188.png
# experiment/Au-CeO2__200_CO_7_250/frame00189.png
# experiment/Au-CeO2__200_CO_7_250/frame00190.png
# experiment/Au-CeO2__200_CO_7_250/frame00191.png
# experiment/Au-CeO2__200_CO_7_250/frame00192.png
# experiment/Au-CeO2__200_CO_7_250/frame00193.png
# experiment/Au-CeO2__200_CO_7_250/frame00194.png
# experiment/Au-CeO2__200_CO_7_250/frame00195.png
# experiment/Au-CeO2__200_CO_7_250/frame00196.png
# experiment/Au-CeO2__200_CO_7_250/frame00197.png
# experiment/Au-CeO2__200_CO_7_250/frame00198.png
# experiment/Au-CeO2__200_CO_7_250/frame00199.png
# experiment/Au-CeO2__200_CO_7_250/frame00200.png
# experiment/Au-CeO2__200_CO_7_250/frame00201.png

# %%
cmd = 'convert -delay 10 -quality 95 @{} movie_pei.mp4'.format(filenames)
print(cmd)
os.system(cmd)
# Out:
# convert -delay 10 -quality 95 @/var/folders/cq/5k4g7j_j5q3crgmh_glgp8yr0000gn/T/tmpnrjzmoc7/files.txt movie_pei.mp4
# 0

# %%
# del tmpdirectory
